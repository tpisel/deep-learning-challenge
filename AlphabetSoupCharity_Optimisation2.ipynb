# %%
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

tf.random.set_seed(123)

# tf_df = pd.read_parquet('data/transformed.parquet')
tf_df = pd.read_parquet('data/nottransformed.parquet')

tf_df.head(10).T
# Out:
#                                  0       1     2     3       4     5      6  \
# STATUS                           1       1     1     1       1     1      1
# SPECIAL_CONSIDERATIONS           0       0     0     0       0     0      0
# ASK_AMT                       5000  108590  5000  6692  142590  5000  31452
# IS_SUCCESSFUL                    1       1     0     1       1     1      1
# AFFILIATION_CompanySponsored     0       0     1     1       0     0      0
# AFFILIATION_Family/Parent        0       0     0     0       0     0      0
# AFFILIATION_Independent          1       1     0     0       1     1      1
# AFFILIATION_National             0       0     0     0       0     0      0
# AFFILIATION_Other                0       0     0     0       0     0      0
# AFFILIATION_Regional             0       0     0     0       0     0      0
# APPLICATION_TYPE_T10             1       0     0     0       0     0      0
# APPLICATION_TYPE_T19             0       0     0     0       0     0      0
# APPLICATION_TYPE_T3              0       1     0     1       1     1      1
# APPLICATION_TYPE_T4              0       0     0     0       0     0      0
# APPLICATION_TYPE_T5              0       0     1     0       0     0      0
# APPLICATION_TYPE_T6              0       0     0     0       0     0      0
# APPLICATION_TYPE_T7              0       0     0     0       0     0      0
# APPLICATION_TYPE_T8              0       0     0     0       0     0      0
# APPLICATION_TYPE_other           0       0     0     0       0     0      0
# CLASSIFICATION_C1000             1       0     0     0       1     0      1
# CLASSIFICATION_C1200             0       0     0     0       0     1      0
# CLASSIFICATION_C2000             0       1     0     1       0     0      0
# CLASSIFICATION_C2100             0       0     0     0       0     0      0
# CLASSIFICATION_C3000             0       0     1     0       0     0      0
# CLASSIFICATION_other             0       0     0     0       0     0      0
# INCOME_AMT_0                     1       0     1     0       0     1      0
# INCOME_AMT_1-9999                0       1     0     0       0     0      0
# INCOME_AMT_10000-24999           0       0     0     1       0     0      0
# INCOME_AMT_100000-499999         0       0     0     0       1     0      1
# INCOME_AMT_10M-50M               0       0     0     0       0     0      0
# INCOME_AMT_1M-5M                 0       0     0     0       0     0      0
# INCOME_AMT_25000-99999           0       0     0     0       0     0      0
# INCOME_AMT_50M+                  0       0     0     0       0     0      0
# INCOME_AMT_5M-10M                0       0     0     0       0     0      0
# ORGANIZATION_Association         1       0     1     0       0     0      0
# ORGANIZATION_Co-operative        0       1     0     0       0     0      0
# ORGANIZATION_Corporation         0       0     0     0       0     0      0
# ORGANIZATION_Trust               0       0     0     1       1     1      1
# USE_CASE_CommunityServ           0       0     0     0       0     0      0
# USE_CASE_Heathcare               0       0     0     0       1     0      0
# USE_CASE_Other                   0       0     0     0       0     0      0
# USE_CASE_Preservation            0       1     0     1       0     1      1
# USE_CASE_ProductDev              1       0     1     0       0     0      0
#
#                                     7      8     9
# STATUS                              1      1     1
# SPECIAL_CONSIDERATIONS              0      0     0
# ASK_AMT                       7508025  94389  5000
# IS_SUCCESSFUL                       1      1     0
# AFFILIATION_CompanySponsored        0      0     1
# AFFILIATION_Family/Parent           0      0     0
# AFFILIATION_Independent             1      1     0
# AFFILIATION_National                0      0     0
# AFFILIATION_Other                   0      0     0
# AFFILIATION_Regional                0      0     0
# APPLICATION_TYPE_T10                0      0     0
# APPLICATION_TYPE_T19                0      0     0
# APPLICATION_TYPE_T3                 1      0     0
# APPLICATION_TYPE_T4                 0      0     0
# APPLICATION_TYPE_T5                 0      0     1
# APPLICATION_TYPE_T6                 0      0     0
# APPLICATION_TYPE_T7                 0      1     0
# APPLICATION_TYPE_T8                 0      0     0
# APPLICATION_TYPE_other              0      0     0
# CLASSIFICATION_C1000                0      1     0
# CLASSIFICATION_C1200                0      0     0
# CLASSIFICATION_C2000                1      0     0
# CLASSIFICATION_C2100                0      0     0
# CLASSIFICATION_C3000                0      0     1
# CLASSIFICATION_other                0      0     0
# INCOME_AMT_0                        0      0     1
# INCOME_AMT_1-9999                   0      1     0
# INCOME_AMT_10000-24999              0      0     0
# INCOME_AMT_100000-499999            0      0     0
# INCOME_AMT_10M-50M                  1      0     0
# INCOME_AMT_1M-5M                    0      0     0
# INCOME_AMT_25000-99999              0      0     0
# INCOME_AMT_50M+                     0      0     0
# INCOME_AMT_5M-10M                   0      0     0
# ORGANIZATION_Association            0      0     1
# ORGANIZATION_Co-operative           0      0     0
# ORGANIZATION_Corporation            0      0     0
# ORGANIZATION_Trust                  1      1     0
# USE_CASE_CommunityServ              0      0     0
# USE_CASE_Heathcare                  0      0     0
# USE_CASE_Other                      0      0     0
# USE_CASE_Preservation               1      0     0
# USE_CASE_ProductDev                 0      1     1

# %%
# this time we'll just scale ASK_AMT directly

v_max = max(tf_df['ASK_AMT'])
v_min = min(tf_df['ASK_AMT'])

tf_df['ASK_AMT'] = (tf_df['ASK_AMT']-v_min)/(v_max-v_min)

# %%
tf_df.shape
# Out:
# (34299, 43)

# %%
# Split our preprocessed data into our features and target arrays
y = tf_df['IS_SUCCESSFUL'].values
X = tf_df.drop(columns='IS_SUCCESSFUL').values

# %%
# Define a range of hyperparameters to search over
learning_rates = [0.001, 0.01, 0.1]
batch_sizes = [32, 64, 128]
layer_configs = [(64, 32), (128, 64), (256, 128)]  # Varying the units in each layer
activation_functions = ['relu', 'tanh', 'sigmoid']

best_accuracy = 0
best_hyperparameters = {}



# in four nested loops, we test each variation of the above
# the final nested loop performs k-fold cross-validation, k=4

kf = StratifiedKFold(n_splits=4, shuffle=True, random_state=132)

n_features = len(tf_df.columns) - 1
iteration = 0
total_iterations = len(learning_rates) * len(batch_sizes) * len(layer_configs) * len(activation_functions)

for learning_rate in learning_rates:
    for batch_size in batch_sizes:
        for layer_config in layer_configs:
            for activation_func in activation_functions:
                iteration += 1
                print(f"Iteration {iteration}/{total_iterations}: Learning Rate = {learning_rate}, Batch Size = {batch_size}, Layer Config = {layer_config}, Activation = {activation_func}")

                val_accuracies = []

                for train_idx, val_idx in kf.split(X, y):
                    nn = tf.keras.models.Sequential()

                    # Adding variable layers and units
                    nn.add(Dense(units=layer_config[0], activation=activation_func, input_dim=n_features))
                    nn.add(Dropout(0.5))
                    nn.add(Dense(units=layer_config[1], activation=activation_func))
                    
                    # Output layer
                    nn.add(Dense(units=1, activation='sigmoid'))

                    nn.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate), metrics=['accuracy'])

                    X_fold, X_val_fold = X[train_idx], X[val_idx]
                    y_fold, y_val_fold = y[train_idx], y[val_idx]

                    early_stopping = EarlyStopping(monitor='val_accuracy', patience=10)

                    fit_model = nn.fit(X_fold, y_fold, epochs=100, batch_size=batch_size, verbose=0, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stopping])

                    _, val_accuracy = nn.evaluate(X_val_fold, y_val_fold, verbose=0)
                    val_accuracies.append(val_accuracy)

                avg_val_accuracy = np.mean(val_accuracies)

                if avg_val_accuracy > best_accuracy:
                    best_accuracy = avg_val_accuracy
                    best_hyperparameters = {'learning_rate': learning_rate, 'batch_size': batch_size, 'layer_config': layer_config, 'activation_func': activation_func}

print("Best Hyperparameters:", best_hyperparameters)
print("Best Validation Accuracy:", best_accuracy)
# Out:
# Iteration 1/81: Learning Rate = 0.001, Batch Size = 32, Layer Config = (64, 32), Activation = relu
# Iteration 2/81: Learning Rate = 0.001, Batch Size = 32, Layer Config = (64, 32), Activation = tanh
# Iteration 3/81: Learning Rate = 0.001, Batch Size = 32, Layer Config = (64, 32), Activation = sigmoid
# Iteration 4/81: Learning Rate = 0.001, Batch Size = 32, Layer Config = (128, 64), Activation = relu
# Iteration 5/81: Learning Rate = 0.001, Batch Size = 32, Layer Config = (128, 64), Activation = tanh
# Iteration 6/81: Learning Rate = 0.001, Batch Size = 32, Layer Config = (128, 64), Activation = sigmoid
# Iteration 7/81: Learning Rate = 0.001, Batch Size = 32, Layer Config = (256, 128), Activation = relu
# Iteration 8/81: Learning Rate = 0.001, Batch Size = 32, Layer Config = (256, 128), Activation = tanh
# Iteration 9/81: Learning Rate = 0.001, Batch Size = 32, Layer Config = (256, 128), Activation = sigmoid
# Iteration 10/81: Learning Rate = 0.001, Batch Size = 64, Layer Config = (64, 32), Activation = relu
# Iteration 11/81: Learning Rate = 0.001, Batch Size = 64, Layer Config = (64, 32), Activation = tanh
# Iteration 12/81: Learning Rate = 0.001, Batch Size = 64, Layer Config = (64, 32), Activation = sigmoid
# Iteration 13/81: Learning Rate = 0.001, Batch Size = 64, Layer Config = (128, 64), Activation = relu
# Iteration 14/81: Learning Rate = 0.001, Batch Size = 64, Layer Config = (128, 64), Activation = tanh
# Iteration 15/81: Learning Rate = 0.001, Batch Size = 64, Layer Config = (128, 64), Activation = sigmoid
# Iteration 16/81: Learning Rate = 0.001, Batch Size = 64, Layer Config = (256, 128), Activation = relu
# Iteration 17/81: Learning Rate = 0.001, Batch Size = 64, Layer Config = (256, 128), Activation = tanh
# Iteration 18/81: Learning Rate = 0.001, Batch Size = 64, Layer Config = (256, 128), Activation = sigmoid
# Iteration 19/81: Learning Rate = 0.001, Batch Size = 128, Layer Config = (64, 32), Activation = relu
# Iteration 20/81: Learning Rate = 0.001, Batch Size = 128, Layer Config = (64, 32), Activation = tanh
# Iteration 21/81: Learning Rate = 0.001, Batch Size = 128, Layer Config = (64, 32), Activation = sigmoid
# Iteration 22/81: Learning Rate = 0.001, Batch Size = 128, Layer Config = (128, 64), Activation = relu
# Iteration 23/81: Learning Rate = 0.001, Batch Size = 128, Layer Config = (128, 64), Activation = tanh
# Iteration 24/81: Learning Rate = 0.001, Batch Size = 128, Layer Config = (128, 64), Activation = sigmoid
# Iteration 25/81: Learning Rate = 0.001, Batch Size = 128, Layer Config = (256, 128), Activation = relu
# Iteration 26/81: Learning Rate = 0.001, Batch Size = 128, Layer Config = (256, 128), Activation = tanh
# Iteration 27/81: Learning Rate = 0.001, Batch Size = 128, Layer Config = (256, 128), Activation = sigmoid
# Iteration 28/81: Learning Rate = 0.01, Batch Size = 32, Layer Config = (64, 32), Activation = relu
# Iteration 29/81: Learning Rate = 0.01, Batch Size = 32, Layer Config = (64, 32), Activation = tanh
# Iteration 30/81: Learning Rate = 0.01, Batch Size = 32, Layer Config = (64, 32), Activation = sigmoid
# Iteration 31/81: Learning Rate = 0.01, Batch Size = 32, Layer Config = (128, 64), Activation = relu
# Iteration 32/81: Learning Rate = 0.01, Batch Size = 32, Layer Config = (128, 64), Activation = tanh
# Iteration 33/81: Learning Rate = 0.01, Batch Size = 32, Layer Config = (128, 64), Activation = sigmoid
# Iteration 34/81: Learning Rate = 0.01, Batch Size = 32, Layer Config = (256, 128), Activation = relu
# Iteration 35/81: Learning Rate = 0.01, Batch Size = 32, Layer Config = (256, 128), Activation = tanh
# Iteration 36/81: Learning Rate = 0.01, Batch Size = 32, Layer Config = (256, 128), Activation = sigmoid
# Iteration 37/81: Learning Rate = 0.01, Batch Size = 64, Layer Config = (64, 32), Activation = relu
# Iteration 38/81: Learning Rate = 0.01, Batch Size = 64, Layer Config = (64, 32), Activation = tanh
# Iteration 39/81: Learning Rate = 0.01, Batch Size = 64, Layer Config = (64, 32), Activation = sigmoid
# Iteration 40/81: Learning Rate = 0.01, Batch Size = 64, Layer Config = (128, 64), Activation = relu
# Iteration 41/81: Learning Rate = 0.01, Batch Size = 64, Layer Config = (128, 64), Activation = tanh
# Iteration 42/81: Learning Rate = 0.01, Batch Size = 64, Layer Config = (128, 64), Activation = sigmoid
# Iteration 43/81: Learning Rate = 0.01, Batch Size = 64, Layer Config = (256, 128), Activation = relu
# Iteration 44/81: Learning Rate = 0.01, Batch Size = 64, Layer Config = (256, 128), Activation = tanh
# Iteration 45/81: Learning Rate = 0.01, Batch Size = 64, Layer Config = (256, 128), Activation = sigmoid
# Iteration 46/81: Learning Rate = 0.01, Batch Size = 128, Layer Config = (64, 32), Activation = relu
# Iteration 47/81: Learning Rate = 0.01, Batch Size = 128, Layer Config = (64, 32), Activation = tanh
# Iteration 48/81: Learning Rate = 0.01, Batch Size = 128, Layer Config = (64, 32), Activation = sigmoid
# Iteration 49/81: Learning Rate = 0.01, Batch Size = 128, Layer Config = (128, 64), Activation = relu
# Iteration 50/81: Learning Rate = 0.01, Batch Size = 128, Layer Config = (128, 64), Activation = tanh
# Iteration 51/81: Learning Rate = 0.01, Batch Size = 128, Layer Config = (128, 64), Activation = sigmoid
# Iteration 52/81: Learning Rate = 0.01, Batch Size = 128, Layer Config = (256, 128), Activation = relu
# Iteration 53/81: Learning Rate = 0.01, Batch Size = 128, Layer Config = (256, 128), Activation = tanh
# Iteration 54/81: Learning Rate = 0.01, Batch Size = 128, Layer Config = (256, 128), Activation = sigmoid
# Iteration 55/81: Learning Rate = 0.1, Batch Size = 32, Layer Config = (64, 32), Activation = relu
# Iteration 56/81: Learning Rate = 0.1, Batch Size = 32, Layer Config = (64, 32), Activation = tanh
# Iteration 57/81: Learning Rate = 0.1, Batch Size = 32, Layer Config = (64, 32), Activation = sigmoid
# Iteration 58/81: Learning Rate = 0.1, Batch Size = 32, Layer Config = (128, 64), Activation = relu
# Iteration 59/81: Learning Rate = 0.1, Batch Size = 32, Layer Config = (128, 64), Activation = tanh
# Iteration 60/81: Learning Rate = 0.1, Batch Size = 32, Layer Config = (128, 64), Activation = sigmoid
# Iteration 61/81: Learning Rate = 0.1, Batch Size = 32, Layer Config = (256, 128), Activation = relu
# Iteration 62/81: Learning Rate = 0.1, Batch Size = 32, Layer Config = (256, 128), Activation = tanh
# Iteration 63/81: Learning Rate = 0.1, Batch Size = 32, Layer Config = (256, 128), Activation = sigmoid
# Iteration 64/81: Learning Rate = 0.1, Batch Size = 64, Layer Config = (64, 32), Activation = relu
# Iteration 65/81: Learning Rate = 0.1, Batch Size = 64, Layer Config = (64, 32), Activation = tanh
# Iteration 66/81: Learning Rate = 0.1, Batch Size = 64, Layer Config = (64, 32), Activation = sigmoid
# Iteration 67/81: Learning Rate = 0.1, Batch Size = 64, Layer Config = (128, 64), Activation = relu
# Iteration 68/81: Learning Rate = 0.1, Batch Size = 64, Layer Config = (128, 64), Activation = tanh
# Iteration 69/81: Learning Rate = 0.1, Batch Size = 64, Layer Config = (128, 64), Activation = sigmoid
# Iteration 70/81: Learning Rate = 0.1, Batch Size = 64, Layer Config = (256, 128), Activation = relu
# Iteration 71/81: Learning Rate = 0.1, Batch Size = 64, Layer Config = (256, 128), Activation = tanh
# Iteration 72/81: Learning Rate = 0.1, Batch Size = 64, Layer Config = (256, 128), Activation = sigmoid
# Iteration 73/81: Learning Rate = 0.1, Batch Size = 128, Layer Config = (64, 32), Activation = relu
# Iteration 74/81: Learning Rate = 0.1, Batch Size = 128, Layer Config = (64, 32), Activation = tanh
# Iteration 75/81: Learning Rate = 0.1, Batch Size = 128, Layer Config = (64, 32), Activation = sigmoid
# Iteration 76/81: Learning Rate = 0.1, Batch Size = 128, Layer Config = (128, 64), Activation = relu
# Iteration 77/81: Learning Rate = 0.1, Batch Size = 128, Layer Config = (128, 64), Activation = tanh
# Iteration 78/81: Learning Rate = 0.1, Batch Size = 128, Layer Config = (128, 64), Activation = sigmoid
# Iteration 79/81: Learning Rate = 0.1, Batch Size = 128, Layer Config = (256, 128), Activation = relu
# Iteration 80/81: Learning Rate = 0.1, Batch Size = 128, Layer Config = (256, 128), Activation = tanh
# Iteration 81/81: Learning Rate = 0.1, Batch Size = 128, Layer Config = (256, 128), Activation = sigmoid
# Best Hyperparameters: {'learning_rate': 0.01, 'batch_size': 128, 'layer_config': (64, 32), 'activation_func': 'sigmoid'}
# Best Validation Accuracy: 0.7317123860120773
